# %%
import pandas as pd

df = pd.read_parquet("../data/processed/processed_data.parquet")

# %%
df['review_clean'] = df['review'].str.replace(r"<\w+>", "", regex=True)
df['review_clean'] = df['review'].str.replace(r"<\w+\/>", "", regex=True)
df['review_clean'] = df['review'].str.strip()

# %%
df.head()
# Out:
#    review_id                                             review  voted_up  \
# 0  232591722  this game is good yes but if you have a bad wi...     False
# 1  232591709  game crashed when anticheat is launched... spe...     False
# 4  232588494                                buggy piece of ♥♥♥♥     False
# 7  232585606  Division 7 versus Division 4 is unfair; it's t...     False
# 9  232584328  Game dosent run, drops to 10 fps and isnt play...     False
#
#    votes_up         review_date  refunded  playtime language  \
# 0         0 2026-08-11 16:29:11     False      26.3       en
# 1         0 2026-08-11 16:28:58     False      53.0       en
# 4         0 2026-08-11 15:42:16     False      43.0       en
# 7         0 2026-08-11 14:58:37     False      93.8       en
# 9         0 2026-08-11 14:39:24     False       3.6       en
#
#                                         review_clean
# 0  this game is good yes but if you have a bad wi...
# ...
